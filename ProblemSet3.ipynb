# %% [markdown]
# # Question 1

# %%
#Step 1. Import the necessary libraries
import pandas as pd   

#Step 2. Import the dataset from this address.
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user" 

#Step 3. Assign it to a variable called users
users = pd.read_csv(url,delimiter='|')    

#Step 4. Discover what is the mean age per occupation
mean_age_per_occupation = users.groupby('occupation')['age'].mean()  
print("\n Mean age per occupation:")
print(mean_age_per_occupation)

#Step 5. Discover the Male ratio per occupation and sort it from the most to the least
male_count_per_occupation = users[users['gender'] == 'M'].groupby('occupation').size()
total_count_per_occupation = users.groupby('occupation').size()
male_ratio_per_occupation = (male_count_per_occupation / total_count_per_occupation).sort_values(ascending=False)  
print("\n Male ratio per occupation is:")
print(male_ratio_per_occupation)

#Step 6. For each occupation, calculate the minimum and maximum ages
min_max_age_per_occupation = users.groupby('occupation')['age'].agg(['min', 'max'])   
print("\n Minimum and maximum age is:")
print(min_max_age_per_occupation)

#Step 7. For each combination of occupation and sex, calculate the mean age
mean_age_per_occupation_sex = users.groupby(['occupation', 'gender'])['age'].mean()  
print("\n Mean age per comination is:")
print(mean_age_per_occupation_sex)

#Step 8. For each occupation present the percentage of women and men.
female_count_per_occupation = users[users['gender'] == 'F'].groupby('occupation').size()   
female_percentage_per_occupation = (female_count_per_occupation / total_count_per_occupation * 100).sort_values(ascending=False)
male_percentage_per_occupation = (100 - female_percentage_per_occupation).sort_values(ascending=False)
print("\n Female Percentage per Occupation:")
print(female_percentage_per_occupation)
print("\n Male Percentage per Occupation:")
print(male_percentage_per_occupation)
# Out:
#  Mean age per occupation:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64
#
#  Male ratio per occupation is:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# ...

# %% [markdown]
# # Question 2

# %%
import pandas as pd

# Step 2: Import the dataset from the provided address
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
euro12 = pd.read_csv(url)

# Step 4: Select only the 'Goals' column
goals = euro12['Goals']
print("Goals column:")
print(goals)

# Step 5: How many teams participated in Euro2012?
num_teams = euro12['Team'].nunique()
print(f"\nNumber of teams that participated in Euro2012: {num_teams}")

# Step 6: What is the number of columns in the dataset?
num_columns = euro12.shape[1]
print(f"\nNumber of columns in the dataset: {num_columns}")

# Step 7: View only the columns 'Team', 'Yellow Cards', and 'Red Cards' and assign them to a dataframe called 'discipline'
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
print("\nDiscipline DataFrame:")
print(discipline)

# Step 8: Sort the teams by 'Red Cards', then by 'Yellow Cards'
sorted_discipline = discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=[False, False])
print("\nSorted Discipline DataFrame:")
print(sorted_discipline)

# Step 9: Calculate the mean 'Yellow Cards' given per Team
mean_yellow_cards = euro12.groupby('Team')['Yellow Cards'].mean()
print("\nMean Yellow Cards per Team:")
print(mean_yellow_cards)

# Step 10: Filter teams that scored more than 6 goals
teams_scored_more_than_6 = euro12[euro12['Goals'] > 6]
print("\nTeams that scored more than 6 goals:")
print(teams_scored_more_than_6)

# Step 11: Select the teams that start with 'G'
teams_starting_with_G = euro12[euro12['Team'].str.startswith('G')]
print("\nTeams that start with 'G':")
print(teams_starting_with_G)

# Step 12: Select the first 7 columns
first_7_columns = euro12.iloc[:, :7]
print("\nFirst 7 columns:")
print(first_7_columns)

# Step 13: Select all columns except the last 3
all_except_last_3 = euro12.iloc[:, :-3]
print("\nAll columns except the last 3:")
print(all_except_last_3)

# Step 14: Present only the 'Shooting Accuracy' from England, Italy, and Russia
teams_of_interest = euro12[euro12['Team'].isin(['England', 'Italy', 'Russia'])]
shooting_accuracy = teams_of_interest[['Team', 'Shooting Accuracy']]
print("\nShooting Accuracy from England, Italy, and Russia:")
print(shooting_accuracy)
# Out:
# Goals column:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64
#
# Number of teams that participated in Euro2012: 16
#
# Number of columns in the dataset: 35
#
# Discipline DataFrame:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# ...

# %% [markdown]
# # Question 3

# %%
import pandas as pd
import numpy as np

# Step 2: Create 3 different Series, each of length 100
# Series 1: Random numbers from 1 to 4
series1 = pd.Series(np.random.randint(1, 5, size=100))

# Series 2: Random numbers from 1 to 3
series2 = pd.Series(np.random.randint(1, 4, size=100))

# Series 3: Random numbers from 10,000 to 30,000
series3 = pd.Series(np.random.randint(10000, 30001, size=100))

# Step 3: Create a DataFrame by joining the Series by column
df = pd.DataFrame({
    'bedrs': series1,
    'bathrs': series2,
    'price_sqr_meter': series3
})

print("DataFrame:")
print(df.head())  # Print the first few rows to check the DataFrame

# Step 4: Change the name of the columns to 'bedrs', 'bathrs', 'price_sqr_meter'
# This is already done in the DataFrame creation, so this step is effectively complete.

# Step 5: Create a one-column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
bigcolumn = pd.DataFrame({
    'bigcolumn': pd.concat([series1, series2, series3], ignore_index=True)
})

print("\nbigcolumn DataFrame:")
print(bigcolumn.head())  # Print the first few rows to check

# Step 6: Check if 'bigcolumn' goes only until index 99
print("\nDoes 'bigcolumn' go until index 99?")
print(bigcolumn.index[-1] == 99)

# Step 7: Reindex the DataFrame so it goes from 0 to 299
bigcolumn_reindexed = bigcolumn.reset_index(drop=True)
print("\nReindexed 'bigcolumn' DataFrame:")
print(bigcolumn_reindexed.head())  # Print the first few rows to check
print(bigcolumn_reindexed.index[-1])  # Print the last index to verify reindexing
# Out:
# DataFrame:
#    bedrs  bathrs  price_sqr_meter
# 0      4       3            18738
# 1      3       1            29239
# 2      2       1            27018
# 3      1       2            22375
# 4      2       2            28080
#
# bigcolumn DataFrame:
#    bigcolumn
# 0          4
# 1          3
# 2          2
# 3          1
# 4          2
#
# Does 'bigcolumn' go until index 99?
# False
#
# Reindexed 'bigcolumn' DataFrame:
#    bigcolumn
# 0          4
# 1          3
# 2          2
# 3          1
# 4          2
# 299

# %% [markdown]
# # Question 4

# %%
import pandas as pd
import numpy as np

# Step 2: Import the dataset from the file
data = pd.read_csv('wind.txt', delim_whitespace=True)

# Step 3: Replace the first 3 columns with a proper datetime index
data['Date'] = pd.to_datetime(data[['Yr', 'Mo', 'Dy']].astype(str).agg('-'.join, axis=1), format='%y-%m-%d')
data.set_index('Date', inplace=True)
data = data.drop(columns=['Yr', 'Mo', 'Dy'])
print(data)

# Step 4: Fix year 2061 by replacing it with 1961
def fix_year(year):
    if year == 2061:
        return 1961
    return year

data.index = data.index.to_series().apply(lambda x: x.replace(year=fix_year(x.year)))

# Step 5: Ensure the datetime index is of type datetime64[ns]
data.index = pd.to_datetime(data.index)

# Step 6: Compute how many values are missing for each location
missing_values = data.isna().sum()
print("Missing values for each location:\n", missing_values)

# Step 7: Compute the total number of non-missing values
total_non_missing = data.notna().sum().sum()
print("Total number of non-missing values:", total_non_missing)

# Step 8: Calculate the mean windspeeds of the windspeeds over all locations and times
mean_windspeed = data.mean().mean()
print("Mean windspeeds across all locations and times:", mean_windspeed)

# Step 9: Create a DataFrame called loc_stats and calculate min, max, mean, and std for each location
loc_stats = data.agg(['min', 'max', 'mean', 'std'])
print("Statistics for each location:\n", loc_stats)

# Step 10: Create a DataFrame called day_stats and calculate min, max, mean, and std for each day
day_stats = data.agg(['min', 'max', 'mean', 'std'], axis=1)
print("Daily statistics across all locations:\n", day_stats)

# Step 11: Find the average windspeed in January for each location
january_data = data[data.index.month == 1]
january_averages = january_data.groupby(january_data.index.year).mean()
print("Average windspeed in January for each location:\n", january_averages)

# Step 12: Downsample the record to a yearly frequency for each location
yearly_data = data.resample('Y').mean()
print("Yearly frequency data:\n", yearly_data)

# Step 13: Downsample the record to a monthly frequency for each location
monthly_data = data.resample('M').mean()
print("Monthly frequency data:\n", monthly_data)

# Step 14: Downsample the record to a weekly frequency for each location
weekly_data = data.resample('W').mean()
print("Weekly frequency data:\n", weekly_data)

# Step 15: Calculate min, max, mean, and std of windspeeds across all locations for each week
weekly_stats = data.resample('W').agg(['min', 'max', 'mean', 'std'])
print("Weekly statistics across all locations:\n", weekly_stats)
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 2061-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04   9.79
# 2061-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN   8.50
# 2061-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79   5.83
# 2061-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54  10.92
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1978-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59  14.04
# 1978-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25  15.25
# 1978-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46  14.50
# 1978-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87  12.46
# 1978-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63  11.58
#
#               CLO    BEL    MAL
# Date
# 2061-01-01  12.58  18.50  15.04
# ...

# %% [markdown]
# # Question 5

# %%
import pandas as pd
import numpy as np

# Step 2: Import the dataset from the address
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url,delimiter='\t') #step3

# Step 4: See the first 10 entries
print("First 10 entries:")
print(chipo.head(10))

# Step 5: What is the number of observations in the dataset?
num_observations = chipo.shape[0]
print(f"\nNumber of observations: {num_observations}")

# Step 6: What is the number of columns in the dataset?
num_columns = chipo.shape[1]
print(f"Number of columns: {num_columns}")

# Step 7: Print the name of all the columns
print("\nColumn names:")
print(chipo.columns.tolist())

# Step 8: How is the dataset indexed?
print("\nIndex information:")
print(chipo.index)

# Step 9: Which was the most-ordered item?
most_ordered_item = chipo['item_name'].mode()[0]
print(f"\nMost-ordered item: {most_ordered_item}")

# Step 10: For the most-ordered item, how many items were ordered?
most_ordered_item_count = chipo[chipo['item_name'] == most_ordered_item]['quantity'].sum()
print(f"Total quantity ordered for {most_ordered_item}: {most_ordered_item_count}")

# Step 11: What was the most ordered item in the choice_description column?
most_ordered_choice = chipo['choice_description'].mode()[0]
print(f"\nMost ordered choice description: {most_ordered_choice}")

# Step 12: How many items were ordered in total?
total_items_ordered = chipo['quantity'].sum()
print(f"\nTotal number of items ordered: {total_items_ordered}")

# Step 13:
# Turn the item price into a float
chipo['item_price'] = chipo['item_price'].replace('[\$,]', '', regex=True).astype(float)

# Check the item price type
print(f"\nItem price type after conversion: {chipo['item_price'].dtype}")

# Create a lambda function to change the type of item price
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x))

# Check the item price type again
print(f"Item price type after applying lambda function: {chipo['item_price'].dtype}")

# Step 14: How much was the revenue for the period in the dataset?
chipo['revenue'] = chipo['item_price'] * chipo['quantity']
total_revenue = chipo['revenue'].sum()
print(f"\nTotal revenue: ${total_revenue:.2f}")

# Step 15: How many orders were made in the period?
num_orders = chipo['order_id'].nunique()
print(f"\nTotal number of orders: {num_orders}")

# Step 16: What is the average revenue amount per order?
average_revenue_per_order = chipo.groupby('order_id')['revenue'].sum().mean()
print(f"\nAverage revenue per order: ${average_revenue_per_order:.2f}")

# Step 17: How many different items are sold?
num_different_items = chipo['item_name'].nunique()
print(f"\nNumber of different items sold: {num_different_items}")
# Out:
# First 10 entries:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# # Question 6
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend.Don't forget to label your axes!

# %%
# Step 1: Import the necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Step 2: Import the dataset 
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')

# Step 3: Prepare the data
data['Year'] = pd.to_datetime(data['Year'], format='%Y').dt.year

# Plotting
plt.figure(figsize=(12, 6))

# Step 4: Create line plots
plt.plot(data['Year'], data['Marriages_per_1000'], label='Marriages per 1000 people', color='blue')
plt.plot(data['Year'], data['Divorces_per_1000'], label='Divorces per 1000 people', color='red')

# Add labels and title
plt.xlabel('Year')
plt.ylabel('Rate per 1000 person')
plt.title('Number of Marriages and Divorces per 1000 person in the U.S. (1867-2014)')
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Question 7
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data from CSV file
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')

# Filter data for the years 1900, 1950, and 2000
years_of_interest = ['1900', '1950', '2000']
filtered_data = data[data['Year'].astype(str).isin(years_of_interest)]

# Extract relevant columns
years = filtered_data['Year']
marriages_per_capita = filtered_data['Marriages_per_1000']
divorces_per_capita = filtered_data['Divorces_per_1000']

# Position of bars on x-axis
x = np.arange(len(years))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()

# Bars for marriages
bars1 = ax.bar(x - width/2, marriages_per_capita, width, label='Marriages per 1,000 People', color='blue')

# Bars for divorces
bars2 = ax.bar(x + width/2, divorces_per_capita, width, label='Divorces per 1,000 People', color='red')

# Add some text for labels, title, and custom x-axis tick labels
ax.set_xlabel('Year')
ax.set_ylabel('Number per 1,000 People')
ax.set_title('Comparison of Marriages and Divorces Per Capita in the U.S. (1900, 1950, 2000)')
ax.set_xticks(x)
ax.set_xticklabels(years)
ax.legend()

# Add value labels on top of bars
def add_value_labels(bars):
    """Add labels on top of bars"""
    for bar in bars:
        height = bar.get_height()
        ax.annotate(f'{height:.1f}',
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_value_labels(bars1)
add_value_labels(bars2)

fig.tight_layout()

plt.show()

# %% [markdown]
# # Question 8
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('actor_kill_counts.csv')

# Sort the data by Kill_Count in descending order
sorted_data = data.sort_values(by='Count', ascending=False)

# Extract the data for plotting
actors = sorted_data['Actor']
kill_counts = sorted_data['Count']

# Create a horizontal bar chart
plt.figure(figsize=(10, 6))

bars = plt.barh(actors, kill_counts, color='skyblue')

# Add labels and title
plt.xlabel('Kill Count')
plt.ylabel('Actor')
plt.title('Deadliest Actors in Hollywood by Kill Count')

# Add value labels on the bars
def add_value_labels(bars):
    """Add labels to the bars"""
    for bar in bars:
        width = bar.get_width()
        plt.text(width, bar.get_y() + bar.get_height() / 2,
                 f'{width}', va='center', ha='left')

add_value_labels(bars)

plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# # Question 9
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('roman-emperor-reigns.csv')

# Process the data to count the number of assassinated and non-assassinated emperors
# Standardize the cause of death to handle variations
data['Cause_of_Death'] = data['Cause_of_Death'].str.lower()
assassinated_count = data['Cause_of_Death'].str.contains('assassinated').sum()
non_assassinated_count = len(data) - assassinated_count

# Prepare data for the pie chart
labels = ['Assassinated', 'Not Assassinated']
sizes = [assassinated_count, non_assassinated_count]
colors = ['red', 'green']
explode = (0.1, 0)  # explode the 1st slice (Assassinated)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',
        shadow=True, startangle=140)

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

# Add a title
plt.title('Fraction of Roman Emperors Assassinated')

# Show the plot
plt.show()

# %% [markdown]
# # Question 10
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from CSV file
data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')

# Create a scatter plot
plt.figure(figsize=(10, 6))

# Scatter plot with color representing the year
scatter = plt.scatter(
    data['Total Arcade Revenue (billions)'], 
    data['Computer Science Doctorates Awarded (US)'], 
    c=data['Year'], 
    cmap='viridis',  # Colormap for coloring
    edgecolor='k',  # Color of the edge of the markers
    s=100  # Size of the markers
)

# Add color bar to indicate the year
plt.colorbar(scatter, label='Year')

# Label the axes
plt.xlabel('Arcade Revenue (in Billions)')
plt.ylabel('Number of Computer Science PhDs Awarded')
plt.title('Relationship Between Arcade Revenue and Number of CS PhDs (2000-2009)')

# Show the plot
plt.show()
